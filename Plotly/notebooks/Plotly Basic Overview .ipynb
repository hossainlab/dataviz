# %% [markdown]
# <h1>Table of Contents(Overview of Plotly)<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Overview-of-Plotly" data-toc-modified-id="Overview-of-Plotly-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Overview of Plotly</a></span><ul class="toc-item"><li><span><a href="#Plot-with-Matplotlib" data-toc-modified-id="Plot-with-Matplotlib-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Plot with Matplotlib</a></span></li><li><span><a href="#Plot-with-Plotly" data-toc-modified-id="Plot-with-Plotly-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Plot with Plotly</a></span></li><li><span><a href="#Scatter-Plot" data-toc-modified-id="Scatter-Plot-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Scatter Plot</a></span><ul class="toc-item"><li><span><a href="#Layout" data-toc-modified-id="Layout-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Layout</a></span></li><li><span><a href="#Customization" data-toc-modified-id="Customization-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Customization</a></span></li></ul></li><li><span><a href="#Line-Charts" data-toc-modified-id="Line-Charts-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Line Charts</a></span></li><li><span><a href="#Bar-Charts" data-toc-modified-id="Bar-Charts-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Bar Charts</a></span><ul class="toc-item"><li><span><a href="#Create-Simple-Bar-Plot" data-toc-modified-id="Create-Simple-Bar-Plot-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Create Simple Bar Plot</a></span></li><li><span><a href="#Comparison-between-Variables" data-toc-modified-id="Comparison-between-Variables-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Comparison between Variables</a></span></li><li><span><a href="#Stacked-Bar-Plot" data-toc-modified-id="Stacked-Bar-Plot-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Stacked Bar Plot</a></span></li></ul></li><li><span><a href="#Bubble-Plot" data-toc-modified-id="Bubble-Plot-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Bubble Plot</a></span></li><li><span><a href="#Boxplots" data-toc-modified-id="Boxplots-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Boxplots</a></span><ul class="toc-item"><li><span><a href="#Single-Boxplot" data-toc-modified-id="Single-Boxplot-1.7.1"><span class="toc-item-num">1.7.1&nbsp;&nbsp;</span>Single Boxplot</a></span></li><li><span><a href="#Show-Outliers" data-toc-modified-id="Show-Outliers-1.7.2"><span class="toc-item-num">1.7.2&nbsp;&nbsp;</span>Show Outliers</a></span></li><li><span><a href="#Grouped-Boxplot" data-toc-modified-id="Grouped-Boxplot-1.7.3"><span class="toc-item-num">1.7.3&nbsp;&nbsp;</span>Grouped Boxplot</a></span></li></ul></li><li><span><a href="#Histograms" data-toc-modified-id="Histograms-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Histograms</a></span></li><li><span><a href="#Heatmaps" data-toc-modified-id="Heatmaps-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Heatmaps</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Overview of Plotly

# %%
# Essential imports for constructing data and plotting
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import plotly.offline as pyo
import plotly.graph_objs as go 
import plotly.figure_factory as ff 
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %% [markdown]
# ## Plot with Matplotlib

# %%
# Create fake dataset to plot 
df = pd.DataFrame(np.random.rand(100, 4), columns=['A', 'B', 'C', 'D'])
df.plot()
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# [<a href="#Overview-of-Plotly">Back to Top<a>]

# %% [markdown]
# ## Plot with Plotly

# %%
# Create a fake dataset to show in plot 
df = pd.DataFrame(np.random.rand(100, 4), columns=['A', 'B', 'C', 'D'])
pyo.plot([
    {'x': df.index, 'y': df[col], 'name': col} for col in df.columns
])
# Out:
# 'temp-plot.html'

# %% [markdown]
# ## Scatter Plot

# %%
np.random.seed(42)
random_x = np.random.randint(1, 101, 100)
random_y = np.random.randint(1, 101, 100)

data = [go.Scatter(
    x = random_x,
    y = random_y, 
    mode= 'markers'
)]

pyo.plot(data, filename='scatter.html')
# Out:
# 'scatter.html'

# %% [markdown]
# ### Layout

# %%
# Set random values for plotting 
np.random.seed(42)
random_x = np.random.randint(1, 101, 100)
random_y = np.random.randint(1, 101, 100)

# Create data and plot 
data = [go.Scatter(
    x = random_x,
    y = random_y, 
    mode = 'markers'
)]


# Create layout 
layout = go.Layout(
    title = 'Random Data Scatterplot', # Graph title
    xaxis = dict(title = 'Some random x-values'), # x-axis label
    yaxis = dict(title = 'Some random y-values'), # y-axis label
    hovermode ='closest' # handles multiple points landing on the same vertical
)
fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename='../outputs/scatter2.html')
# Out:
# '../outputs/scatter2.html'

# %% [markdown]
# ### Customization

# %%
# Set random values for plotting 
np.random.seed(42)
random_x = np.random.randint(1, 101, 100)
random_y = np.random.randint(1, 101, 100)

# Create data and plot 
data = [go.Scatter(
    x = random_x,
    y = random_y, 
    mode = 'markers',
    # Change marker style 
    marker = dict(
        size = 12,
        color = 'rgb(51, 204, 153)',
        symbol = 'pentagon', 
        line = dict(
            width = 2, 
        )
    )
)]

# Create layout 
layout = go.Layout(
    title = 'Random Data Scatterplot', # Graph title
    xaxis = dict(title = 'Some random x-values'), # x-axis label
    yaxis = dict(title = 'Some random y-values'), # y-axis label
    hovermode ='closest' # handles multiple points landing on the same vertical
)

# Create figure and exported as html file 
fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename='../outputs/scatter3.html')
# Out:
# '../outputs/scatter3.html'

# %% [markdown]
# [<a href="#Overview-of-Plotly">Back to Top<a>]

# %% [markdown]
# ## Line Charts

# %%
np.random.seed(56)
x_values = np.linspace(0, 1, 100) # 100 evenly spaced values
y_values = np.random.randn(100) # 100 random values

# Create traces 
trace0 = go.Scatter(
    x = x_values, 
    y = y_values+5,
    mode= 'markers',
    name = 'markers'
)

trace1 = go.Scatter(
    x = x_values, 
    y = y_values,
    mode= 'lines+markers', 
    name = 'lines+markers'
)

trace2 = go.Scatter(
    x = x_values, 
    y = y_values-5, 
    mode= 'lines', 
    name = 'lines'
)

# Create data 
data = [trace0, trace1, trace2]

# Create layout 
layout = go.Layout(
    title = 'Line charts showing different methods.'
)

fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename="../outputs/line.html")
# Out:
# '../outputs/line.html'

# %%
# Read a csv file from local computer 
df = pd.read_csv("../data/population.csv", index_col=0)

# %%
# Examine first few rows
df.head()
# Out:
#                PopEstimate2010  PopEstimate2011  PopEstimate2012  \
# Name
# Connecticut            3580171          3591927          3597705
# Maine                  1327568          1327968          1328101
# Massachusetts          6564943          6612178          6659627
# New Hampshire          1316700          1318345          1320923
# Rhode Island           1053169          1052154          1052761
#
#                PopEstimate2013  PopEstimate2014  PopEstimate2015  \
# Name
# Connecticut            3602470          3600188          3593862
# Maine                  1327975          1328903          1327787
# Massachusetts          6711138          6757925          6794002
# New Hampshire          1322622          1328684          1330134
# Rhode Island           1052784          1054782          1055916
#
#                PopEstimate2016  PopEstimate2017
# Name
# Connecticut            3587685          3588184
# Maine                  1330232          1335907
# ...

# %%
# Create traces 
traces = [go.Scatter(
    x = df.columns, 
    y = df.loc[name], 
    mode = 'markers+lines', 
    name = name 
)for name in df.index]

# Create layout 
layout = go.Layout(
    title = 'Population Estimates of the Six New England States.'
)

# Create figure 
fig = go.Figure(data=traces, layout=layout)
pyo.plot(fig, filename="../outputs/line2.html")
# Out:
# '../outputs/line2.html'

# %% [markdown]
# [<a href="#Overview-of-Plotly">Back to Top<a>]

# %% [markdown]
# ## Bar Charts

# %%
# Read data 
df = pd.read_csv("../data/2018WinterOlympics.csv")

# %%
# Examine first few rows 
df.head()
# Out:
#    Rank            NOC  Gold  Silver  Bronze  Total
# 0     1         Norway    14      14      11     39
# 1     2        Germany    14      10       7     31
# 2     3         Canada    11       8      10     29
# 3     4  United States     9       8       6     23
# 4     5    Netherlands     8       6       6     20

# %% [markdown]
# ### Create Simple Bar Plot

# %%
# Create traces 
data = [go.Bar(
    x = df['NOC'], # NOC stands for National Olympic Committee
    y = df['Total'], 
)]

# Create layout 
layout = go.Layout(
    title = '2018 Winter Olympic Medals by Country.'
)

# Create figure 
fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename=("../outputs/bar.html"))
# Out:
# '../outputs/bar.html'

# %%
# Take a look at data again..
df.head()
# Out:
#    Rank            NOC  Gold  Silver  Bronze  Total
# 0     1         Norway    14      14      11     39
# 1     2        Germany    14      10       7     31
# 2     3         Canada    11       8      10     29
# 3     4  United States     9       8       6     23
# 4     5    Netherlands     8       6       6     20

# %% [markdown]
# ### Comparison between Variables

# %%
# Create traces 
trace1 = go.Bar(
    x = df['NOC'], 
    y = df['Gold'], 
    name = 'Gold', 
    marker = dict(color='#FFD700')
)

trace2 = go.Bar(
    x = df['NOC'], 
    y = df['Silver'], 
    name = 'Silver', 
    marker = dict(color='#9EA0A1')
)

trace3 = go.Bar(
    x = df['NOC'], 
    y = df['Bronze'], 
    name = 'Bronze', 
    marker = dict(color='#CD5F32')
)

# Store traces in data 
data = [trace1, trace2, trace3]

# Create layout 
layout = go.Layout(
    title = '2018 Winter Olympic Medals by Country.'
)

# Create figure 
fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename="../outputs/bar2.html")
# Out:
# '../outputs/bar2.html'

# %% [markdown]
# ### Stacked Bar Plot

# %%
# Create traces 
trace1 = go.Bar(
    x = df['NOC'], 
    y = df['Gold'], 
    name = 'Gold', 
    marker = dict(color='#FFD700')
)

trace2 = go.Bar(
    x = df['NOC'], 
    y = df['Silver'], 
    name = 'Silver', 
    marker = dict(color='#9EA0A1')
)

trace3 = go.Bar(
    x = df['NOC'], 
    y = df['Bronze'], 
    name = 'Bronze', 
    marker = dict(color='#CD5F32')
)

# Store traces in data 
data = [trace1, trace2, trace3]

# Create layout 
layout = go.Layout(
    title = '2018 Winter Olympic Medals by Country.', 
    barmode = 'stack'
)

# Create figure 
fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename="../outputs/bar_stacked.html")
# Out:
# '../outputs/bar_stacked.html'

# %% [markdown]
# [<a href="#Overview-of-Plotly">Back to Top<a>]

# %% [markdown]
# ## Bubble Plot

# %%
# Read data 
df = pd.read_csv("../data/mpg.csv")

# %%
# Examine first few rows 
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
data =  go.Scatter(
    x = df['horsepower'], 
    y = df['mpg'],
    text= df['name'], 
    mode = 'markers', 
    marker= dict(size=1.5 * df['cylinders']) # set the marker size 
)

layout = go.Layout(
    title = 'Veichke mpg vs. horsepower.', 
    xaxis = dict(title='horsepower'), 
    yaxis = dict(title='mpg'), 
    hovermode= 'closest'
)

fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename=("../outputs/bubble.html"))
# Out:
# '../outputs/bubble.html'

# %% [markdown]
# [<a href="#Overview-of-Plotly">Back to Top<a>]

# %% [markdown]
# ## Boxplots

# %%
# Load iris dataset
import seaborn as sns 
iris = sns.load_dataset('iris')

# %%
# Examine first few rows 
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Single Boxplot

# %%
data = go.Box(
    x = iris['species'], 
    y = iris['sepal_length'], 
    boxpoints= 'all', # display the original data points
    jitter=0.3, # spread them out so they all appear
    pointpos=-1.8    # offset them to the left of the box

)

layout = go.Layout(
    title = 'Boxplot of Species and Sepal Length', 
    xaxis = dict(title='Species'), 
    yaxis = dict(title='Sepal Length')
)

fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename=("../outputs/box1.html"))
# Out:
# '../outputs/box1.html'

# %% [markdown]
# ### Show Outliers

# %%
data = go.Box(
    x = iris['species'], 
    y = iris['petal_length'], 
    boxpoints= 'outliers'
)

layout = go.Layout(
    title = 'Boxplot of Species and Petal Length', 
    xaxis = dict(title='Species'), 
    yaxis = dict(title='Petal Length'), 
)

fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename=("../outputs/box2.html"))
# Out:
# '../outputs/box2.html'

# %% [markdown]
# ### Grouped Boxplot

# %%
trace1 = go.Box(
    x = iris['species'], 
    y = iris['petal_length'], 
    boxpoints= 'outliers', 
    name = 'Petal Length'
)

trace2 = go.Box(
    x = iris['species'], 
    y = iris['petal_width'], 
    boxpoints= 'outliers', 
    name = 'Petal Width'

)

trace3 = go.Box(
    x = iris['species'], 
    y = iris['sepal_length'], 
    boxpoints= 'outliers', 
    name = 'Sepal Length'

)

trace4 = go.Box(
    x = iris['species'], 
    y = iris['sepal_width'], 
    boxpoints= 'outliers', 
    name = 'Sepal Width'

)


layout = go.Layout(
    title = 'Boxplot of Iris Dataset', 
)

data = [trace1, trace2, trace3, trace4]
fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename=("../outputs/box3.html"))
# Out:
# '../outputs/box3.html'

# %% [markdown]
# [<a href="#Overview-of-Plotly">Back to Top<a>]

# %% [markdown]
# ## Histograms

# %%
data = go.Histogram(
    x = iris['sepal_length'], 
)

layout = go.Layout(
    title = 'Histogram of Sepal Length', 
    
)

fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename=("../outputs/hist1.html"))
# Out:
# '../outputs/hist1.html'

# %%
df = pd.read_csv("../data/mpg.csv")
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
data = go.Histogram(
    x = df['mpg'], 
    xbins=dict(start=8, end=50, size=6)
)

layout = go.Layout(
    title = 'Histogram of MPG', 
)

fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename=("../outputs/hist2.html"))
# Out:
# '../outputs/hist2.html'

# %%
data = go.Histogram(
    x = df['mpg'], 
    xbins=dict(start=8, end=50, size=1)
)

layout = go.Layout(
    title = 'Histogram of MPG', 
)

fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename=("../outputs/hist3.html"))
# Out:
# '../outputs/hist3.html'

# %%
data = go.Histogram(
    x = df['mpg'], 
    xbins=dict(start=8, end=50, size=.5)
)

layout = go.Layout(
    title = 'Histogram of MPG', 
)

fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename=("../outputs/hist4.html"))
# Out:
# '../outputs/hist4.html'

# %%
df = pd.read_csv("../data/arrhythmia.csv")
df.head()
# Out:
#    Age  Sex  Height
# 0   68    1     146
# 1   58    1     148
# 2   36    1     149
# 3   34    1     150
# 4   40    1     150

# %%
data = [go.Histogram(
    x=df[df['Sex']==0]['Height'],
    opacity=0.75,
    name = 'Male'
),
go.Histogram(
    x=df[df['Sex']==1]['Height'],
    opacity=0.75,
    name = 'Female'
)]


layout = go.Layout(
    title = 'Height Comparison by Gender',
    barmode='overlay'
)


fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename=("../outputs/hist5.html"))
# Out:
# '../outputs/hist5.html'

# %%
x = np.random.randn(1000)
hist_data = [x]
group_labels = ['distplot']

fig = ff.create_distplot(hist_data, group_labels)
pyo.plot(fig, filename='../outputs/basic_distplot.html')
# Out:
# '../outputs/basic_distplot.html'

# %% [markdown]
# [<a href="#Overview-of-Plotly">Back to Top<a>]

# %% [markdown]
# ## Heatmaps

# %%
df = pd.read_csv("../data/2010SantaBarbaraCA.csv")
df.head()
# Out:
#    LST_DATE      DAY LST_TIME  T_HR_AVG
# 0  20100601  TUESDAY     0:00      12.7
# 1  20100601  TUESDAY     1:00      12.7
# 2  20100601  TUESDAY     2:00      12.3
# 3  20100601  TUESDAY     3:00      12.5
# 4  20100601  TUESDAY     4:00      12.7

# %%
# Create X, Y, Z data 
data = [go.Heatmap(
    x = df['DAY'], 
    y = df['LST_TIME'], 
    z = df['T_HR_AVG'].values.tolist(), 
    colorscale= 'Jet'
)]

# Create layout
layout = go.Layout(
    title = 'Hourly Temperatures, June 1-7, 2010', 
)

# Create figure
fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename="../outputs/heatmap.html")

# %%
# Create data 
import plotly.offline as pyo
import plotly.graph_objs as go
from plotly import tools
import pandas as pd

df1 = pd.read_csv('../data/2010SitkaAK.csv')
df2 = pd.read_csv('../data/2010SantaBarbaraCA.csv')
df3 = pd.read_csv('../data/2010YumaAZ.csv')

trace1 = go.Heatmap(
    x=df1['DAY'],
    y=df1['LST_TIME'],
    z=df1['T_HR_AVG'].values.tolist(),
    colorscale='Jet',
    zmin = 5, zmax = 40 # add max/min color values to make each plot consistent
)
trace2 = go.Heatmap(
    x=df2['DAY'],
    y=df2['LST_TIME'],
    z=df2['T_HR_AVG'].values.tolist(),
    colorscale='Jet',
    zmin = 5, zmax = 40
)
trace3 = go.Heatmap(
    x=df3['DAY'],
    y=df3['LST_TIME'],
    z=df3['T_HR_AVG'].values.tolist(),
    colorscale='Jet',
    zmin = 5, zmax = 40
)

fig = tools.make_subplots(rows=1, cols=3,
    subplot_titles=('Sitka, AK','Santa Barbara, CA', 'Yuma, AZ'),
    shared_yaxes = True,  # this makes the hours appear only on the left
)
fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)
fig.append_trace(trace3, 1, 3)

fig['layout'].update(      # access the layout directly!
    title='Hourly Temperatures, June 1-7, 2010'
)
pyo.plot(fig, filename='../outputs/AllThree.html')
# Out:
# /home/jubayer/anaconda3/lib/python3.7/site-packages/plotly/tools.py:465: DeprecationWarning:
#
# plotly.tools.make_subplots is deprecated, please use plotly.subplots.make_subplots instead
# '../outputs/AllThree.html'

# %% [markdown]
# [<a href="#Overview-of-Plotly">Back to Top<a>]
