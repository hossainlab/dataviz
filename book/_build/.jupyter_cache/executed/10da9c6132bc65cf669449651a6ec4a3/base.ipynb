# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

matplotlib.interactive(True)
plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
np.random.seed()

# %%
y = np.random.uniform(low=0.0, high=1000, size=(1000,))
y.sort()

x = np.arange(len(y))

# %%
plt.plot(x, y)

plt.grid(True)

plt.yscale('linear')

plt.show()

# %%
plt.plot(x, y)
plt.grid(True)

plt.yscale('log')

plt.show()

# %%
plt.plot(x, y)
plt.grid(True)

plt.yscale('log', basey=2)

plt.show()
# Out:
# /home/jubayer/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   after removing the cwd from sys.path.

# %%
plt.plot(x, y)
plt.grid(True)

plt.yscale('log', basey=10)

plt.xscale('log', basex=2)

plt.show()
# Out:
# /home/jubayer/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   after removing the cwd from sys.path.
# /home/jubayer/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: The 'basex' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.

# %%
y = 100 * np.random.normal(size=1000)
y.sort()

x = np.arange(len(y))

# %%
plt.plot(x, y)
plt.grid(True)

plt.yscale('linear')

plt.show()

# %%
plt.plot(x, y)
plt.grid(True)

plt.yscale('log')

plt.show()

# %%
plt.plot(x, y)
plt.grid(True)

plt.yscale('symlog')

plt.show()

# %%
plt.plot(x, y)
plt.grid(True)

plt.yscale('symlog', linthreshy=10)

plt.show()
# Out:
# /home/jubayer/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: The 'linthreshy' parameter of __init__() has been renamed 'linthresh' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   after removing the cwd from sys.path.

# %%
y = np.random.uniform(low=0.0, high=1.0, size=(1000,))
y.sort()

x = np.arange(len(y))

# %%
plt.plot(x, y)
plt.grid(True)

plt.yscale('linear')

plt.show()

# %%
plt.plot(x, y)
plt.grid(True)

plt.yscale('log')

plt.show()

# %%
from matplotlib.ticker import NullFormatter

# %%
plt.plot(x, y)
plt.grid(True)

plt.yscale('logit')
plt.gca().yaxis.set_minor_formatter(NullFormatter())

plt.show()

# %%
plt.plot(x, y)
plt.grid(True)

plt.yscale('logit')

plt.show()
