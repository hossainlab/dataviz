# %%
import plotly.plotly as py
import plotly.graph_objs as go
import pandas as pd
import plotly.offline as offline

offline.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ## Two Y-Axes
# It is often useful to view two different plots - which have the same X axis values, but different Y values - together. In such instances, we can use two Y axes to visualize the two plots.

# %% [markdown]
# #### Generate the first trace

# %%
trace0 = go.Scatter(x = [1, 2, 3], 
                    y = [10,20,30],
                    
                    name = 'yaxis data'
                   )

# %% [markdown]
# #### Create a second trace and map to a second Y axis
# When we set yaxis to 'y2' (the default is 'y'), it means that this axis is a associated with the <b>yaxis2</b> attribute in the layout definition (which we will see shortly)

# %%
trace1 = go.Scatter(x = [5, 6, 7],
                    y = [4, 5, 8],
                    
                    name = 'yaxis2 data',
                    
                    yaxis = 'y2'
)

# %% [markdown]
# #### The data for our plot includes the lines from the two traces

# %%
data = [trace0, trace1]

# %% [markdown]
# #### Define the layout which includes the second Y axis
# <b>yaxis2</b> is set to be an overlay on the Y axis which means it will become a second Y axis. We set its position to be on the right side of the axes.
#
# Note that we can overlay the X axis as well and place axes on the left, right, top and bottom depending on which axis is being overlayed.

# %%
layout = go.Layout(title = 'Double Y Axis Example',
                   yaxis = dict(title = 'Default Y Axis'),
                   
                   yaxis2 = dict(title = 'Second Y Axis',
                                 titlefont = dict(color='orange'),
                               
                                 overlaying = 'y',
                                 side = 'right'
                              )
                  )

# %% [markdown]
# #### Plot the figure with the two Y axes

# %%
fig = go.Figure(data=data, 
                layout=layout)

offline.iplot(fig)
# Out:
# <div id="95605edf-8e31-4cf4-8882-aa852f4b65fc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("95605edf-8e31-4cf4-8882-aa852f4b65fc", [{"type": "scatter", "x": [1, 2, 3], "y": [10, 20, 30], "name": "yaxis data"}, {"type": "scatter", "x": [5, 6, 7], "y": [4, 5, 8], "name": "yaxis2 data", "yaxis": "y2"}], {"title": "Double Y Axis Example", "yaxis": {"title": "Default Y Axis"}, "yaxis2": {"title": "Second Y Axis", "titlefont": {"color": "orange"}, "overlaying": "y", "side": "right"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# #### We can have more than two Y axes
# We generate a third trace and map it to yaxis3 in the layout definition by setting its yaxis value to 'y3'.
#
# We redefine our data

# %%
trace2 = go.Scatter(x = [8, 9, 12],
                    y = [120, 140, 150],
                    
                    name = 'yaxis3 data',
                    
                    yaxis = 'y3'
)

# %% [markdown]
# #### Redefine our data to include the 3 traces

# %%
data = [trace0, trace1, trace2]

# %% [markdown]
# #### Define the new layout to include the 3rd Y axis
# There is a minor difference between this and the addition of the second axis. This is because if we place the 3rd axis on the right of the plot, as with the 2nd axis, they will overlap.
#
# We set the value of the <b>anchor</b> attribute for the 3rd axis to 'free'. This allows us to specify the position of the axis on a relative scale along the opposite axis (i.e. a Y axis's posion on the X axis). Here we place this 3rd axis 90% of the way to the right along the X axis.

# %%
layout = go.Layout(title = 'Three Y Axes',
                   yaxis = dict(title='Default Y Axis'),
                   
                   yaxis2 = dict(title='Second Y Axis',
                                 titlefont=dict(color='orange'),
                               
                                 overlaying='y',
                                 side='right'
                              ),
                   
                   yaxis3 = dict(title='Third Y Axis',
                                 titlefont=dict(color='green'),
                               
                                 overlaying='y',
                                 side='right',
                                 
                                 anchor = 'free',
                                 position = 0.9
                              )
                  )

# %%
fig = go.Figure(data=data, 
                layout=layout)

offline.iplot(fig)
# Out:
# <div id="d51c6503-ba42-4d77-a626-5b319f213169" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d51c6503-ba42-4d77-a626-5b319f213169", [{"type": "scatter", "x": [1, 2, 3], "y": [10, 20, 30], "name": "yaxis data"}, {"type": "scatter", "x": [5, 6, 7], "y": [4, 5, 8], "name": "yaxis2 data", "yaxis": "y2"}, {"type": "scatter", "x": [8, 9, 12], "y": [120, 140, 150], "name": "yaxis3 data", "yaxis": "y3"}], {"title": "Three Y Axes", "yaxis": {"title": "Default Y Axis"}, "yaxis2": {"title": "Second Y Axis", "titlefont": {"color": "orange"}, "overlaying": "y", "side": "right"}, "yaxis3": {"title": "Third Y Axis", "titlefont": {"color": "green"}, "overlaying": "y", "side": "right", "anchor": "free", "position": 0.9}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ## Avocado dataset
# This dataset contains the production and price (per piece) of various kinds of avocados from different regions in the United States between Jan 2014 and March 2018.
#
# Download the dataset here: https://www.kaggle.com/neuromusic/avocado-prices

# %%
data = pd.read_csv('datasets/avocado.csv')
data.head()
# Out:
#    Index        Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1      1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2      2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3      3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4      4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %% [markdown]
# #### We restrict the data under consideration
# To get unique dates in our series, we restrict our data to organic avocados from California

# %%
data_ca = data.loc[(data['region'] == 'California') & (data['type'] == 'organic')]

# %% [markdown]
# #### We sort the data by date
# This is generate a meaningful time series

# %%
data_ca = data_ca.sort_values(by = ['Date'])
data_ca.head()
# Out:
#       Index        Date  AveragePrice  Total Volume       4046      4225  \
# 9489     51  2015-01-04          1.24     142349.77  107490.73  25711.96
# 9488     50  2015-01-11          1.10     158110.68  123712.51  25975.27
# 9487     49  2015-01-18          1.24     195207.60  123138.29  58616.16
# 9486     48  2015-01-25          1.30     121698.02   80952.24  28216.13
# 9485     47  2015-02-01          1.11     196031.90  142332.45  41999.51
#
#       4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 9489  2.93     9144.15     9144.15         0.0          0.0  organic  2015
# 9488  1.47     8421.43     8421.43         0.0          0.0  organic  2015
# 9487  0.00    13453.15    13453.15         0.0          0.0  organic  2015
# 9486  0.00    12529.65    12529.65         0.0          0.0  organic  2015
# 9485  2.92    11697.02    11697.02         0.0          0.0  organic  2015
#
#           region
# 9489  California
# 9488  California
# 9487  California
# 9486  California
# 9485  California

# %% [markdown]
# #### Generate a trace for the avocado average price

# %%
priceTrace = go.Scatter(x = data_ca['Date'],
                        y = data_ca['AveragePrice'],
                    
                        name = 'Average Price'
)

# %% [markdown]
# #### Create a trace for the avocado production
# This will be represented by the 2nd Y axis

# %%
volumeTrace = go.Scatter(x = data_ca['Date'],
                         y = data_ca['Total Volume'],
                    
                         name = 'Total Volume',
                         yaxis = 'y2'
)

# %% [markdown]
# #### The data for the plot includes both the price and volume traces

# %%
avocadoData = [priceTrace, volumeTrace]

# %% [markdown]
# #### Define the layout
# The second Y axis will be on the right, and its title text is in orange

# %%
avocadoLayout = go.Layout(title = 'Avocado Production and Prices',
                          yaxis = dict(title='Average Price'),
                   
                          yaxis2 = dict(title = 'Number of Avocados sold',
                                        titlefont = dict(color = 'orange'),

                                        overlaying = 'y',
                                        side = 'right'
                                )
    
)

# %% [markdown]
# #### Plot the figure
# Notice how there is an inverse relationship between produced quantity and average price per avocado

# %%
fig = go.Figure(data=avocadoData, 
                layout=avocadoLayout)

offline.iplot(fig)
# Out:
# <div id="bf74a95a-d498-480c-a735-eaca947b863c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("bf74a95a-d498-480c-a735-eaca947b863c", [{"type": "scatter", "x": ["2015-01-04", "2015-01-11", "2015-01-18", "2015-01-25", "2015-02-01", "2015-02-08", "2015-02-15", "2015-02-22", "2015-03-01", "2015-03-08", "2015-03-15", "2015-03-22", "2015-03-29", "2015-04-05", "2015-04-12", "2015-04-19", "2015-04-26", "2015-05-03", "2015-05-10", "2015-05-17", "2015-05-24", "2015-05-31", "2015-06-07", "2015-06-14", "2015-06-21", "2015-06-28", "2015-07-05", "2015-07-12", "2015-07-19", "2015-07-26", "2015-08-02", "2015-08-09", "2015-08-16", "2015-08-23", "2015-08-30", "2015-09-06", "2015-09-13", "2015-09-20", "2015-09-27", "2015-10-04", "2015-10-11", "2015-10-18", "2015-10-25", "2015-11-01", "2015-11-08", "2015-11-15", "2015-11-22", "2015-11-29", "2015-12-06", "2015-12-13", "2015-12-20", "2015-12-27", "2016-01-03", "2016-01-10", "2016-01-17", "2016-01-24", "2016-01-31", "2016-02-07", "2016-02-14", "2016-02-21", "2016-02-28", "2016-03-06", "2016-03-13", "2016-03-20", "2016-03-27", "2016-04-03", "2016-04-10", "2016-04-17", "2016-04-24", "2016-05-01", "2016-05-08", "2016-05-15", "2016-05-22", "2016-05-29", "2016-06-05", "2016-06-12", "2016-06-19", "2016-06-26", "2016-07-03", "2016-07-10", "2016-07-17", "2016-07-24", "2016-07-31", "2016-08-07", "2016-08-14", "2016-08-21", "2016-08-28", "2016-09-04", "2016-09-11", "2016-09-18", "2016-09-25", "2016-10-02", "2016-10-09", "2016-10-16", "2016-10-23", "2016-10-30", "2016-11-06", "2016-11-13", "2016-11-20", "2016-11-27", "2016-12-04", "2016-12-11", "2016-12-18", "2016-12-25", "2017-01-01", "2017-01-08", "2017-01-15", "2017-01-22", "2017-01-29", "2017-02-05", "2017-02-12", "2017-02-19", "2017-02-26", "2017-03-05", "2017-03-12", "2017-03-19", "2017-03-26", "2017-